# %% [markdown]
# <a href="https://colab.research.google.com/github/diwakarg05/Neural-Network/blob/main/SECOND_NN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# New dataset (changed input, not digits)
X = np.array([
    [0,0],
    [0,1],
    [1,0],
    [1,1]
])

# Labels (different mapping than XOR so output changes)
y = np.array([[0], [1], [1], [0]])

# %%
# Seed for reproducibility
np.random.seed(42)

# Network architecture
input_size = 2
hidden_size = 4
output_size = 1

# Initialize weights
W1 = np.random.randn(input_size, hidden_size)
b1 = np.zeros((1, hidden_size))

W2 = np.random.randn(hidden_size, output_size)
b2 = np.zeros((1, output_size))

# %%
# Activation functions
def sigmoid(x):
    return 1 / (1 + np.exp(-x))

def sigmoid_derivative(x):
    return x * (1 - x)

# %%
# Training
learning_rate = 0.1
epochs = 10000

for epoch in range(epochs):

    # Forward propagation
    Z1 = np.dot(X, W1) + b1
    A1 = sigmoid(Z1)

    Z2 = np.dot(A1, W2) + b2
    A2 = sigmoid(Z2)

    # Loss (Binary Cross Entropy)
    loss = -np.mean(y * np.log(A2 + 1e-8) + (1 - y) * np.log(1 - A2 + 1e-8))

    # Backpropagation
    dZ2 = A2 - y
    dW2 = np.dot(A1.T, dZ2)
    db2 = np.sum(dZ2, axis=0, keepdims=True)

    dA1 = np.dot(dZ2, W2.T)
    dZ1 = dA1 * sigmoid_derivative(A1)
    dW1 = np.dot(X.T, dZ1)
    db1 = np.sum(dZ1, axis=0, keepdims=True)

# %%
    # Gradient descent
    W1 -= learning_rate * dW1
    b1 -= learning_rate * db1
    W2 -= learning_rate * dW2
    b2 -= learning_rate * db2

    if epoch % 1000 == 0:
        print(f"Epoch {epoch}, Loss: {loss}")

# Final output
print("\nFinal Predictions:")
print(A2)
# Out:
# Final Predictions:
# [[0.39459663]
#  [0.33849512]
#  [0.32609598]
#  [0.29208992]]
